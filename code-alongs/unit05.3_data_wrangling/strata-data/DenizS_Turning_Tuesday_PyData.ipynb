# %% [markdown]
# # Turning Tuesdays
#
# In financial markets, traders talk about the concept of "Turning Tuesday." The idea is that if a market is down for several days in a row, it will never turn around on a Friday because traders don't want to stay in a position over the weekend. Their pessism looms over the weekend. Likewise, on a Monday, traders have been sitting around depressed for the whole weekend (because the market is down) so Monday will stay down. It's on Tuesday that more rational heads prevail, so a down market will more likely "turn around" on a Tuesday.

# %% [markdown]
# ### There is anectdotal evidence to support this....

# %%
from IPython.display import Image
Image(filename='img/wsj_turnaround_tuesday.png')

# %% [markdown]
# ### What does the data say?.... Let's find out!

# %%
import pandas as pd

# %% [markdown]
# ### Get some data!
#
# `#git clone https://github.com/talumbau/strata_data.git`

# %%
sp500 = pd.read_csv("data/table.csv", index_col=0, parse_dates=True)

# %%
sp500.head()
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 2016-01-11  1926.119995  1935.650024  1901.099976  1923.670044  4607290000
# 2016-01-08  1985.319946  1985.319946  1918.459961  1922.030029  4664940000
# 2016-01-07  1985.319946  1985.319946  1938.829956  1943.089966  5076590000
# 2016-01-06  2011.709961  2011.709961  1979.050049  1990.260010  4336660000
# 2016-01-05  2013.780029  2021.939941  2004.170044  2016.709961  3706620000
#
#               Adj Close
# Date
# 2016-01-11  1923.670044
# 2016-01-08  1922.030029
# 2016-01-07  1943.089966
# 2016-01-06  1990.260010
# 2016-01-05  2016.709961

# %%
sptt = sp500[["Adj Close"]]

# %%
sptt.head()
# Out:
#               Adj Close
# Date
# 2016-01-11  1923.670044
# 2016-01-08  1922.030029
# 2016-01-07  1943.089966
# 2016-01-06  1990.260010
# 2016-01-05  2016.709961

# %%
sptt.tail()
# Out:
#             Adj Close
# Date
# 1950-01-09      17.08
# 1950-01-06      16.98
# 1950-01-05      16.93
# 1950-01-04      16.85
# 1950-01-03      16.66

# %% [markdown]
# ### If you have datetime data, it's almost always the right answer to use pandas

# %%
sp500.index
# Out:
# DatetimeIndex(['2016-01-11', '2016-01-08', '2016-01-07', '2016-01-06',
#                '2016-01-05', '2016-01-04', '2015-12-31', '2015-12-30',
#                '2015-12-29', '2015-12-28',
#                ...
#                '1950-01-16', '1950-01-13', '1950-01-12', '1950-01-11',
#                '1950-01-10', '1950-01-09', '1950-01-06', '1950-01-05',
#                '1950-01-04', '1950-01-03'],
#               dtype='datetime64[ns]', name='Date', length=16613, freq=None)

# %% [markdown]
# ### First question: which days did the market go up or down?

# %%
def rel_change(x):
    return (x[0] - x[1])/x[1]

# %%
sptt.assign?

# %%
# https://pandas.pydata.org/pandas-docs/version/1.0.0/user_guide/computation.html#stats-rolling-apply
# sptt = sptt.assign(UpDown=pd.rolling_apply(sptt, 2, rel_change))
sptt['UpDown'] = sptt.rolling(window=2).apply(rel_change, raw=True)
# Out:
# <ipython-input-32-5a952310581b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sptt['UpDown'] = sptt.rolling(window=2).apply(rel_change, raw=True)

# %%
sptt.head(20)
# Out:
#               Adj Close    UpDown
# Date
# 2016-01-11  1923.670044       NaN
# 2016-01-08  1922.030029  0.000853
# 2016-01-07  1943.089966 -0.010838
# 2016-01-06  1990.260010 -0.023700
# 2016-01-05  2016.709961 -0.013115
# 2016-01-04  2012.660034  0.002012
# 2015-12-31  2043.939941 -0.015304
# 2015-12-30  2063.360107 -0.009412
# 2015-12-29  2078.360107 -0.007217
# 2015-12-28  2056.500000  0.010630
# 2015-12-24  2060.989990 -0.002179
# 2015-12-23  2064.290039 -0.001599
# 2015-12-22  2038.969971  0.012418
# 2015-12-21  2021.150024  0.008817
# 2015-12-18  2005.550049  0.007778
# 2015-12-17  2041.890015 -0.017797
# 2015-12-16  2073.070068 -0.015041
# 2015-12-15  2043.410034  0.014515
# 2015-12-14  2021.939941  0.010619
# 2015-12-11  2012.369995  0.004756

# %% [markdown]
# Hmm... we need to shift the results "up" one. January 11 was an "up" day, but its entry is one row too low in the "UpDown" column

# %%
sptt.UpDown = sptt.UpDown.shift(-1)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
sptt.head(20)
# Out:
#               Adj Close    UpDown
# Date
# 2016-01-11  1923.670044  0.000853
# 2016-01-08  1922.030029 -0.010838
# 2016-01-07  1943.089966 -0.023700
# 2016-01-06  1990.260010 -0.013115
# 2016-01-05  2016.709961  0.002012
# 2016-01-04  2012.660034 -0.015304
# 2015-12-31  2043.939941 -0.009412
# 2015-12-30  2063.360107 -0.007217
# 2015-12-29  2078.360107  0.010630
# 2015-12-28  2056.500000 -0.002179
# 2015-12-24  2060.989990 -0.001599
# 2015-12-23  2064.290039  0.012418
# 2015-12-22  2038.969971  0.008817
# 2015-12-21  2021.150024  0.007778
# 2015-12-18  2005.550049 -0.017797
# 2015-12-17  2041.890015 -0.015041
# 2015-12-16  2073.070068  0.014515
# 2015-12-15  2043.410034  0.010619
# 2015-12-14  2021.939941  0.004756
# 2015-12-11  2012.369995 -0.019423

# %%
sptt.tail()
# Out:
#             Adj Close    UpDown
# Date
# 1950-01-09      17.08  0.005889
# 1950-01-06      16.98  0.002953
# 1950-01-05      16.93  0.004748
# 1950-01-04      16.85  0.011405
# 1950-01-03      16.66       NaN

# %% [markdown]
# ### Next question: which day of the week corresponds to each row?

# %%
sptt.index
# Out:
# DatetimeIndex(['2016-01-11', '2016-01-08', '2016-01-07', '2016-01-06',
#                '2016-01-05', '2016-01-04', '2015-12-31', '2015-12-30',
#                '2015-12-29', '2015-12-28',
#                ...
#                '1950-01-16', '1950-01-13', '1950-01-12', '1950-01-11',
#                '1950-01-10', '1950-01-09', '1950-01-06', '1950-01-05',
#                '1950-01-04', '1950-01-03'],
#               dtype='datetime64[ns]', name='Date', length=16613, freq=None)

# %%
dir(sptt.index)
# Out:
# ['T',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__init__',
#  '__init_subclass__',
#  '__inv__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmod__',
#  '__rmul__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__weakref__',
#  '__xor__',
#  '_accessors',
#  '_add_comparison_methods',
#  '_add_logical_methods',
#  '_add_logical_methods_disabled',
#  '_add_numeric_methods',
#  '_add_numeric_methods_add_sub_disabled',
#  '_add_numeric_methods_binary',
#  '_add_numeric_methods_disabled',
#  '_add_numeric_methods_unary',
#  '_assert_can_do_op',
#  '_assert_can_do_setop',
#  '_assert_safe_casting',
#  '_assert_take_fillable',
#  '_attributes',
#  '_bool_ops',
#  '_box_func',
#  '_can_fast_intersect',
#  '_can_fast_union',
#  '_can_hold_identifiers_and_holds_name',
#  '_can_hold_na',
#  '_can_reindex',
#  '_check_indexing_error',
#  '_cleanup',
#  '_coerce_scalar_to_index',
#  '_comparables',
#  '_concat',
#  '_constructor',
#  '_convert_arr_indexer',
#  '_convert_can_do_setop',
#  '_convert_for_op',
#  '_convert_index_indexer',
#  '_convert_list_indexer',
#  '_convert_listlike_indexer',
#  '_convert_slice_indexer',
#  '_convert_tolerance',
#  '_datetimelike_methods',
#  '_datetimelike_ops',
#  '_default_dtype',
#  '_defer_to_indexing',
#  '_deprecations',
#  '_dir_additions',
#  '_dir_deletions',
#  '_engine',
#  '_engine_type',
#  '_fast_union',
#  '_field_ops',
#  '_filter_indexer_tolerance',
#  '_format_attrs',
#  '_format_data',
#  '_format_native_types',
#  '_format_space',
#  '_format_with_header',
#  '_formatter_func',
#  '_get_attributes_dict',
#  '_get_engine_target',
#  '_get_fill_indexer',
#  '_get_fill_indexer_searchsorted',
#  '_get_grouper_for_level',
#  '_get_level_number',
#  '_get_level_values',
#  '_get_names',
#  '_get_nearest_indexer',
#  '_get_partial_string_timestamp_match_key',
#  '_get_reconciled_name_object',
#  '_get_string_slice',
#  '_get_time_micros',
#  '_get_unique_index',
#  '_get_values_for_loc',
#  '_has_complex_internals',
#  '_has_same_tz',
#  '_hasnans',
#  '_id',
#  '_inner_indexer',
#  '_invalid_indexer',
#  '_is_comparable_dtype',
#  '_is_compatible_with_other',
#  '_is_convertible_to_index_for_join',
#  '_is_dates_only',
#  '_is_memory_usage_qualified',
#  '_is_monotonic_decreasing',
#  '_is_monotonic_increasing',
#  '_is_numeric_dtype',
#  '_is_strictly_monotonic_decreasing',
#  '_is_strictly_monotonic_increasing',
#  '_is_unique',
#  '_isnan',
#  '_join_level',
#  '_join_monotonic',
#  '_join_multi',
#  '_join_non_unique',
#  '_join_precedence',
#  '_left_indexer',
#  '_left_indexer_unique',
#  '_map_values',
#  '_maybe_cast_for_get_loc',
#  '_maybe_cast_indexer',
#  '_maybe_cast_slice_bound',
#  '_maybe_promote',
#  '_maybe_utc_convert',
#  '_mpl_repr',
#  '_na_value',
#  '_name',
#  '_nan_idxs',
#  '_no_setting_name',
#  '_object_ops',
#  '_outer_indexer',
#  '_parsed_string_to_bounds',
#  '_partial_date_slice',
#  '_reduce',
#  '_reindex_non_unique',
#  '_reset_cache',
#  '_reset_identity',
#  '_resolution_obj',
#  '_scalar_data_error',
#  '_searchsorted_monotonic',
#  '_set_names',
#  '_shallow_copy',
#  '_should_fallback_to_positional',
#  '_simple_new',
#  '_sort_levels_monotonic',
#  '_string_data_error',
#  '_summary',
#  '_supports_partial_string_indexing',
#  '_to_safe_for_reshape',
#  '_transform_index',
#  '_typ',
#  '_union',
#  '_union_incompatible_dtypes',
#  '_validate_dtype',
#  '_validate_index_level',
#  '_validate_indexer',
#  '_validate_names',
#  '_validate_partial_date_slice',
#  '_validate_positional_slice',
#  '_validate_sort_keyword',
#  '_values',
#  '_with_freq',
#  '_wrap_joined_index',
#  '_wrap_setop_result',
#  'all',
#  'any',
#  'append',
#  'argmax',
#  'argmin',
#  'argsort',
#  'array',
#  'asi8',
#  'asof',
#  'asof_locs',
#  'astype',
#  'ceil',
#  'copy',
#  'date',
#  'day',
#  'day_name',
#  'dayofweek',
#  'dayofyear',
#  'days_in_month',
#  'daysinmonth',
#  'delete',
#  'difference',
#  'drop',
#  'drop_duplicates',
#  'droplevel',
#  'dropna',
#  'dtype',
#  'duplicated',
#  'empty',
#  'equals',
#  'factorize',
#  'fillna',
#  'floor',
#  'format',
#  'freq',
#  'freqstr',
#  'get_indexer',
#  'get_indexer_for',
#  'get_indexer_non_unique',
#  'get_level_values',
#  'get_loc',
#  'get_slice_bound',
#  'get_value',
#  'groupby',
#  'has_duplicates',
#  'hasnans',
#  'holds_integer',
#  'hour',
#  'identical',
#  'indexer_at_time',
#  'indexer_between_time',
#  'inferred_freq',
#  'inferred_type',
#  'insert',
#  'intersection',
#  'is_',
#  'is_all_dates',
#  'is_boolean',
#  'is_categorical',
#  'is_floating',
#  'is_integer',
#  'is_interval',
#  'is_leap_year',
#  'is_mixed',
#  'is_monotonic',
#  'is_monotonic_decreasing',
#  'is_monotonic_increasing',
#  'is_month_end',
#  'is_month_start',
#  'is_normalized',
#  'is_numeric',
#  'is_object',
#  'is_quarter_end',
#  'is_quarter_start',
#  'is_type_compatible',
#  'is_unique',
#  'is_year_end',
#  'is_year_start',
#  'isin',
#  'isna',
#  'isnull',
#  'isocalendar',
#  'item',
#  'join',
#  'map',
#  'max',
#  'mean',
#  'memory_usage',
#  'microsecond',
#  'min',
#  'minute',
#  'month',
#  'month_name',
#  'name',
#  'names',
#  'nanosecond',
#  'nbytes',
#  'ndim',
#  'nlevels',
#  'normalize',
#  'notna',
#  'notnull',
#  'nunique',
#  'putmask',
#  'quarter',
#  'ravel',
#  'reindex',
#  'rename',
#  'repeat',
#  'resolution',
#  'round',
#  'searchsorted',
#  'second',
#  'set_names',
#  'shape',
#  'shift',
#  'size',
#  'slice_indexer',
#  'slice_locs',
#  'snap',
#  'sort',
#  'sort_values',
#  'sortlevel',
#  'strftime',
#  'symmetric_difference',
#  'take',
#  'time',
#  'timetz',
#  'to_flat_index',
#  'to_frame',
#  'to_julian_date',
#  'to_list',
#  'to_native_types',
#  'to_numpy',
#  'to_period',
#  'to_perioddelta',
#  'to_pydatetime',
#  'to_series',
#  'transpose',
#  'tz',
#  'tz_convert',
#  'tz_localize',
#  'tzinfo',
#  'union',
#  'union_many',
#  'unique',
#  'value_counts',
#  'values',
#  'view',
#  'week',
#  'weekday',
#  'weekofyear',
#  'where',
#  'year']

# %%
sptt['day_num'] = sptt.index.dayofweek
# Out:
# <ipython-input-40-01c8c7ec58c3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sptt['day_num'] = sptt.index.dayofweek

# %%
sptt.head(7)
# Out:
#               Adj Close    UpDown  day_num
# Date
# 2016-01-11  1923.670044  0.000853        0
# 2016-01-08  1922.030029 -0.010838        4
# 2016-01-07  1943.089966 -0.023700        3
# 2016-01-06  1990.260010 -0.013115        2
# 2016-01-05  2016.709961  0.002012        1
# 2016-01-04  2012.660034 -0.015304        0
# 2015-12-31  2043.939941 -0.009412        3

# %% [markdown]
# ### Groupby operations! Do calculations over every value that has the same day of week. Ex:

# %%
sptt["Adj Close"].groupby(sptt.index.dayofweek).mean()
# Out:
# Date
# 0    478.334693
# 1    487.397694
# 2    487.905133
# 3    485.221006
# 4    484.926614
# Name: Adj Close, dtype: float64

# %% [markdown]
# ### Let's get more specific with the "Turning Tuesday Hypothesis":
#
# We'll say a "down market" is a market where there are three or more days in a row where the market closes lower than it started. So, for example, for a Thursday, we are interested in what has happened on the three previous tradings days (typically the Monday, Tuesday, and Wednesday directly preceding the Thursday). With that as the definition of a "down market", the question is then, 'When we are in a down market, do we return to an up market more frequently on a Tuesday than on other days of the week?'

# %%
def last_three_days_down(x):
    if x[1]<=0 and x[2]<=0 and x[3]<=0:
        return 1
    else:
        return 0

# %%
# Deprecated
# sptt['ltdd'] = pd.rolling_apply(sptt["UpDown"], 4, last_three_days_down).shift(-3)

# %%
sptt['ltdd'] = sptt.UpDown.rolling(window=4).apply(last_three_days_down, raw=True).shift(-3)
# Out:
# <ipython-input-66-a4a57e68a453>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sptt['ltdd'] = sptt.UpDown.rolling(window=4).apply(last_three_days_down, raw=True).shift(-3)

# %%
sptt.head(10)
# Out:
#               Adj Close    UpDown  day_num  ltdd  turned
# Date
# 2016-01-11  1923.670044  0.000853        0   1.0    True
# 2016-01-08  1922.030029 -0.010838        4   0.0   False
# 2016-01-07  1943.089966 -0.023700        3   0.0   False
# 2016-01-06  1990.260010 -0.013115        2   0.0   False
# 2016-01-05  2016.709961  0.002012        1   1.0    True
# 2016-01-04  2012.660034 -0.015304        0   0.0   False
# 2015-12-31  2043.939941 -0.009412        3   0.0   False
# 2015-12-30  2063.360107 -0.007217        2   0.0   False
# 2015-12-29  2078.360107  0.010630        1   0.0   False
# 2015-12-28  2056.500000 -0.002179        0   0.0   False

# %%
len(sptt)
# Out:
# 16613

# %%
import numpy as np

# %%
sptt.head()
# Out:
#               Adj Close    UpDown  day_num  ltdd  turned
# Date
# 2016-01-11  1923.670044  0.000853        0   1.0    True
# 2016-01-08  1922.030029 -0.010838        4   0.0   False
# 2016-01-07  1943.089966 -0.023700        3   0.0   False
# 2016-01-06  1990.260010 -0.013115        2   0.0   False
# 2016-01-05  2016.709961  0.002012        1   1.0    True

# %%
sptt['turned'] = (sptt['ltdd'] > 0.) & (sptt['UpDown'] > 0.)
# Out:
# <ipython-input-71-37a4380dc9fc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sptt['turned'] = (sptt['ltdd'] > 0.) & (sptt['UpDown'] > 0.)

# %%
sptt.head(50)
# Out:
#               Adj Close    UpDown  day_num  ltdd  turned
# Date
# 2016-01-11  1923.670044  0.000853        0   1.0    True
# 2016-01-08  1922.030029 -0.010838        4   0.0   False
# 2016-01-07  1943.089966 -0.023700        3   0.0   False
# 2016-01-06  1990.260010 -0.013115        2   0.0   False
# 2016-01-05  2016.709961  0.002012        1   1.0    True
# 2016-01-04  2012.660034 -0.015304        0   0.0   False
# 2015-12-31  2043.939941 -0.009412        3   0.0   False
# 2015-12-30  2063.360107 -0.007217        2   0.0   False
# 2015-12-29  2078.360107  0.010630        1   0.0   False
# 2015-12-28  2056.500000 -0.002179        0   0.0   False
# 2015-12-24  2060.989990 -0.001599        3   0.0   False
# 2015-12-23  2064.290039  0.012418        2   0.0   False
# 2015-12-22  2038.969971  0.008817        1   0.0   False
# 2015-12-21  2021.150024  0.007778        0   0.0   False
# 2015-12-18  2005.550049 -0.017797        4   0.0   False
# 2015-12-17  2041.890015 -0.015041        3   0.0   False
# 2015-12-16  2073.070068  0.014515        2   0.0   False
# 2015-12-15  2043.410034  0.010619        1   0.0   False
# 2015-12-14  2021.939941  0.004756        0   0.0   False
# 2015-12-11  2012.369995 -0.019423        4   0.0   False
# 2015-12-10  2052.229980  0.002251        3   1.0    True
# 2015-12-09  2047.619995 -0.007739        2   0.0   False
# 2015-12-08  2063.590088 -0.006490        1   0.0   False
# 2015-12-07  2077.070068 -0.006990        0   0.0   False
# 2015-12-04  2091.689941  0.020526        4   0.0   False
# 2015-12-03  2049.620117 -0.014374        3   0.0   False
# 2015-12-02  2079.510010 -0.010996        2   0.0   False
# 2015-12-01  2102.629883  0.010681        1   0.0   False
# 2015-11-30  2080.409912 -0.004641        0   0.0   False
# 2015-11-27  2090.110107  0.000594        4   0.0   False
# 2015-11-25  2088.870117 -0.000129        2   0.0   False
# 2015-11-24  2089.139893  0.001222        1   0.0   False
# 2015-11-23  2086.590088 -0.001235        0   0.0   False
# 2015-11-20  2089.169922  0.003810        4   0.0   False
# 2015-11-19  2081.239990 -0.001123        3   0.0   False
# 2015-11-18  2083.580078  0.016162        2   0.0   False
# 2015-11-17  2050.439941 -0.001339        1   0.0   False
# 2015-11-16  2053.189941  0.014903        0   1.0    True
# 2015-11-13  2023.040039 -0.011207        4   0.0   False
# 2015-11-12  2045.969971 -0.013990        3   0.0   False
# 2015-11-11  2075.000000 -0.003228        2   0.0   False
# 2015-11-10  2081.719971  0.001511        1   1.0    True
# 2015-11-09  2078.580078 -0.009823        0   1.0   False
# 2015-11-06  2099.199951 -0.000348        4   0.0   False
# 2015-11-05  2099.929932 -0.001132        3   0.0   False
# 2015-11-04  2102.310059 -0.003545        2   0.0   False
# 2015-11-03  2109.790039  0.002728        1   0.0   False
# 2015-11-02  2104.050049  0.011874        0   0.0   False
# 2015-10-30  2079.360107 -0.004810        4   0.0   False
# 2015-10-29  2089.409912 -0.000450        3   0.0   False

# %%
sp_turning_days_totals = sptt.turned.groupby(sptt.index.dayofweek).sum()

# %%
# %matplotlib inline

# %%
sp_turning_days_totals.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
sp_turning_days_totals
# Out:
# Date
# 0    142
# 1    256
# 2    223
# 3    193
# 4    198
# Name: turned, dtype: int64

# %% [markdown]
# ### Ta-dah! Tuesdays really are a magic day! Off to start a hedge fund....
# #### (please don't actually go and start a hedge fund)

# %% [markdown]
# ## Try this:
#
#  - What about 2 days down, then 1 up? Is the pattern the same? 4 days?
#  - Is the day after a Turning Tuesday usually good? Or not?

# %% [markdown]
# # What Next?

# %% [markdown]
# This is a reasonable introduction to pandas, but it really does take practice. In the years since pandas was released the "DataFrame" idiom, originally taken from the R language (and maybe 'S' before that) has become even more ingrained in data tooling. In fact, it's been borrowed for frameworks meant to scale beyond a single machine, like Spark, or dask in the PyData world:

# %%
from IPython.display import Image
Image(filename='img/spark_dataframe.png')

# %%
from IPython.display import Image
Image(filename='img/dask_dataframe.png')

# %% [markdown]
# So, it's worth learning your way around pandas, since current and future library authors want to leverage that knowledge to incentivize users to try out their new data tool.

# %% [markdown]
# ## Thanks for listening!!!

# %% [markdown]
# ### Send me your thoughts via electrons:
#
# ### @talumbau
#
# ### tj.alumbaugh@continuum.io
